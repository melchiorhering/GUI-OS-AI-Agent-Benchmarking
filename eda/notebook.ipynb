# %%
import eda_benchmark as eda


df = eda.collect("../../Spider2-V/evaluation_examples/test_all.json", "../../Spider2-V/evaluation_examples/examples")
figs = eda.make_plots(df)


# display the first figure explicitly in Jupyter
# Out:
# Loaded 494 tasks • 0 missing
